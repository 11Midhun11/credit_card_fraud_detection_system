# %%
import pandas as pd

# %%
import numpy as np

# %%
df=pd.read_csv("bim_cleaned.csv")

# %%
import pandas as pd



# Drop the specified columns
columns_to_drop = [
    'RecordedDate', 'ResponseId', 'Finished', 'Progress', 
    'Duration (in seconds)', 'RecipientEmail', 'ExternalReference', 
    'LocationLatitude', 'LocationLongitude', 'EndDate', 'Status', 
    'IPAddress', 'RecipientLastName', 'RecipientFirstName', 
    'Q_RecaptchaScore', 'StartDate'
]
df_dropped = df.drop(columns=columns_to_drop)

# Save the modified dataframe to a new CSV
final_output_path = 'bim_cleaned_final1.csv'
df_dropped.to_csv(final_output_path, index=False)

print(f"File saved to {final_output_path}")
# Out:
# File saved to bim_cleaned_final1.csv

# %%
df2=pd.read_csv("bim_cleaned_final1.csv")

# %%
df2.head()
# Out:
#                   DistributionChannel                 UserLanguage  \
# 0                Distribution Channel                User Language
# 1  {"ImportId":"distributionChannel"}  {"ImportId":"userLanguage"}
# 2                             preview                           EN
# 3                             preview                           EN
# 4                             preview                           EN
#
#                                                 QID1  \
# 0  Thank you for considering participating in my ...
# 1                                {"ImportId":"QID1"}
# 2      I do not Consent to participate in the survey
# 3      I do not Consent to participate in the survey
# 4             I Consent to participate in the survey
#
#                                                   Q1  \
# 0  What is your current professional role? - Sele...
# 1                                {"ImportId":"QID2"}
# 2                                                NaN
# ...

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder


# Identify categorical columns
categorical_columns = df2.select_dtypes(include=['object']).columns

# Initialize LabelEncoder
label_encoder = LabelEncoder()

# Apply label encoding to each categorical column
for column in categorical_columns:
    df[column] = label_encoder.fit_transform(df[column])

# Alternatively, you could use one-hot encoding
# df = pd.get_dummies(df, columns=categorical_columns)

# Save the converted DataFrame to a new CSV file
df2.to_csv('converted_numerical_data.csv', index=False)

print("Categorical columns have been converted to numerical format.")
# Out:
# Categorical columns have been converted to numerical format.

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# Load the CSV file
file_path = '/mnt/data/bim_cleaned_final1.csv'
df = pd.read_csv(file_path)

# Identify categorical columns
categorical_columns = df.select_dtypes(include=['object']).columns

# Initialize LabelEncoder
label_encoder = LabelEncoder()

# Apply label encoding to each categorical column
for column in categorical_columns:
    df[column] = label_encoder.fit_transform(df[column])

# Select only numeric columns
numeric_df = df2.select_dtypes(include='number')

# Calculate mean, median, mode, standard deviation, and skewness
mean_values = numeric_df.mean()
median_values = numeric_df.median()

# Handle mode calculation, checking if mode calculation returns any value
mode_values = numeric_df.mode()
if not mode_values.empty:
    mode_values = mode_values.iloc[0]
else:
    mode_values = pd.Series([None] * len(numeric_df.columns), index=numeric_df.columns)

std_dev_values = numeric_df.std()

# Combine all the statistics into a single dataframe for better visualization
statistics_df = pd.DataFrame({
    'Mean': mean_values,
    'Median': median_values,
    'Mode': mode_values,
    'Standard Deviation': std_dev_values
})

# Display the statistics
print(statistics_df)

# Optionally, save to a CSV file
statistics_df.to_csv('converted_data_statistics.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[31], line 40
#      32 # Combine all the statistics into a single dataframe for better visualization
#      33 statistics_df = pd.DataFrame({
#      34     'Mean': mean_values,
#      35     'Median': median_values,
#      36     'Mode': mode_values,
#      37     'Standard Deviation': std_dev_values
#      38 })
# ---> 40 import ace_tools as tools; tools.display_dataframe_to_user(name="Converted Data Statistical Analysis", dataframe=statistics_df)
#
# ModuleNotFoundError: No module named 'ace_tools'
